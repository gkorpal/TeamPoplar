# %% [markdown]
# ## Data Cleaning and Preprocessing

# %%
# %matplotlib inline
# We start off with the baseline import statements we need to do the basic data manipulation and visualization.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew
import matplotlib.pyplot as plt
import calendar
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import ElasticNet, Ridge, Lasso
from sklearn.model_selection import KFold, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import RobustScaler
sns.set_style("whitegrid")
import xgboost as xgb

def print_full(x):
    pd.set_option('display.max_rows', len(x))
    print(x)
    pd.reset_option('display.max_rows')

# %%
#We create and set aside a copy of the data for initial exploration
housing_train = pd.read_csv('../data/train.csv')
housing = housing_train.copy()

#MISSING DATA
total = housing.isnull().sum().sort_values(ascending=False)
percent = (housing.isnull().sum()/housing.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])

#CORRELATION CHECK
corr_matrix = housing.corr()
top_corr = corr_matrix['SalePrice'].sort_values(ascending = False)

# %%
#DROPPING SOME COLUMNS
drop = ['PoolQC', 'PoolArea','MiscFeature', 'MiscVal', 'Alley', 'Fence', 'FireplaceQu', 'Fireplaces', 'LotFrontage']
drop2 = ['Id','GarageArea','1stFlrSF','GarageYrBlt','MSSubClass'] 
housing.drop(columns = drop + drop2, inplace = True)
housing['Age'] = housing['YrSold'] - housing['YearBuilt']
housing['AgeRemodel'] = housing['YrSold'] - housing['YearRemodAdd']
housing = housing[housing.AgeRemodel >= 0]
housing = housing[housing.GrLivArea < 4000]
housing.drop(columns = ['YearBuilt','YearRemodAdd'], inplace = True)

# %%
#FURTHER DATA CLEANING
housing_cat = housing.select_dtypes(exclude=[np.number])
housing_numeric = housing.select_dtypes(include=[np.number])

#Numeric
numeric_unbounded = ['LotArea', 'MasVnrArea','BsmtFinSF1','BsmtFinSF2', 'BsmtUnfSF',
                     'TotalBsmtSF','2ndFlrSF','LowQualFinSF','GrLivArea','WoodDeckSF',
                     'OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch', 'SalePrice',
                     'Age','AgeRemodel']

#numeric_one_hot = ['MSSubClass','MoSold']
numeric_one_hot = ['MoSold']
numeric_ordinal = [x for x in housing_numeric.columns 
                   if (x not in numeric_unbounded and x not in numeric_one_hot)]

housing_numeric_unbounded = housing_numeric[numeric_unbounded]
housing_numeric_one_hot = housing_numeric[numeric_one_hot]
housing_numeric_ordinal = housing_numeric[numeric_ordinal]

#housing_numeric_one_hot['MSSubClass'] = housing_numeric_one_hot['MSSubClass'].astype('str')
housing_numeric_one_hot['MoSold'] = housing_numeric_one_hot['MoSold'].replace({i:calendar.month_name[i][:3] for i in range(1,13)})
housing_numeric_one_hot = pd.get_dummies(housing_numeric_one_hot)
#Categorical
cat_ordinal = ['ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
               'BsmtFinType1', 'HeatingQC', 'KitchenQual','Functional','GarageFinish',
               'GarageQual', 'GarageCond']

housing_cat_ordinal = housing_cat[cat_ordinal]
housing_cat_ordinal.fillna('No', inplace = True)
housing_cat_one_hot = housing_cat.drop(columns = cat_ordinal)

housing_cat_one_hot = pd.get_dummies(housing_cat_one_hot)

def mapper(cat):
    if cat in ['ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond', 'GarageQual', 'GarageCond',
               'HeatingQC', 'KitchenQual']:
        mapper = {'No':0, 'Po':1, 'Fa':2,'TA':3,'Gd':4,'Ex':5}
    elif cat == 'BsmtExposure':
            mapper = {'No':0,'No':1, 'Mn':2, 'Av':3,'Gd':4}
    elif cat == 'BsmtFinType1':
        mapper = {'No':0,'Unf':1,'LwQ':2,'Rec':3,'BLQ':4,'ALQ':5,'GLQ':6}
    elif cat == 'Functional':
        mapper = {'Sal':0,'Sev':1,'Maj2':2,'Maj1':3,'Mod':4,'Min2':5, 'Min1':6,'Typ':7}
    else:
        mapper = {'No':0,'Unf':1,'RFn':2,'Fin':3}
        
    return mapper

for cat in cat_ordinal:
    housing_cat_ordinal[cat].replace(mapper(cat), inplace = True)

#Combining numeric and categorical
housing_ordinal = pd.concat([housing_numeric_ordinal,housing_cat_ordinal], axis = 'columns')
housing_one_hot = pd.concat([housing_numeric_one_hot, housing_cat_one_hot], axis = 'columns')
housing_clean = pd.concat([housing_one_hot, housing_ordinal, housing_numeric_unbounded], 
                          axis = 'columns')
#Getting rid of skew
skewed_feats = housing_clean[numeric_unbounded].apply(lambda x: skew(x.dropna())) #compute skewness
skewed_feats = skewed_feats[skewed_feats > 0.75]
skewed_feats = skewed_feats.index

housing_clean[skewed_feats] = np.log1p(housing_clean[skewed_feats])

#MORE CORRELATION
ordinal_prices = pd.concat([housing_ordinal, housing['SalePrice']], axis = 'columns')
ordinal_corr_matrix = ordinal_prices.corr()
top_corr_ordinal = ordinal_corr_matrix['SalePrice'].sort_values(ascending = False)

one_hot_prices = pd.concat([housing_one_hot, housing['SalePrice']], axis = 'columns')
one_hot_corr_matrix = one_hot_prices.corr()
top_corr_one_hot = one_hot_corr_matrix['SalePrice'].filter(like = 'Neighborhood').sort_values(ascending = False)
# Out:
# <ipython-input-9-0ef994b6d77d>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_numeric_one_hot['MoSold'] = housing_numeric_one_hot['MoSold'].replace({i:calendar.month_name[i][:3] for i in range(1,13)})
# C:\Users\abrah\anaconda3\envs\quantum_ML\lib\site-packages\pandas\core\frame.py:4462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
# C:\Users\abrah\anaconda3\envs\quantum_ML\lib\site-packages\pandas\core\series.py:4509: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
#REMOVAL OF THE REMAINING NaN
housing_clean.isnull().sum().sort_values(ascending=False)
df = housing_clean.copy()
problem_col = df.isin([np.nan, np.inf, -np.inf]).sum(axis=0)[df.isin([np.nan, np.inf, -np.inf]).sum(axis=0) != 0] 
index_to_drop = df[problem_col.index[0]][df[problem_col.index[0]].isin([np.nan, np.inf, -np.inf])].index
df.drop(index = index_to_drop, inplace = True)
#df.isnull().sum().sort_values(ascending=False)

# %% [markdown]
# # Interpretability with regularized Linear Regression
# Our goal is to understand the most important features for housing price with a reasonably predictive regularized linear model. We used an elasticnet model to remove features and further fit an elasticnet model on the removed features to understand the most correlated predictors. The final regression features show the most predictive features for increasing and decresing housing prices.

# %%
#Fitting the elasticnet model

kfolds = KFold(n_splits=10, shuffle=True, random_state=69)

X = df.drop(columns = 'SalePrice')
y = (df['SalePrice'])

parameters = {'elastic__alpha': np.logspace(-3.5, -1, 10), 'elastic__l1_ratio': [.1, .5, .7, .9, .95, .99,
1]}
elastic_pipe = Pipeline([('scale',RobustScaler()),
                              ('elastic',ElasticNet())])

elastic_cv = GridSearchCV(elastic_pipe,parameters,scoring='neg_mean_squared_error',cv= kfolds)
elastic_cv.fit(X,y)
# Out:
# GridSearchCV(cv=KFold(n_splits=10, random_state=69, shuffle=True),
#              estimator=Pipeline(steps=[('scale', RobustScaler()),
#                                        ('elastic', ElasticNet())]),
#              param_grid={'elastic__alpha': array([0.00031623, 0.00059948, 0.00113646, 0.00215443, 0.00408424,
#        0.00774264, 0.01467799, 0.02782559, 0.05274997, 0.1       ]),
#                          'elastic__l1_ratio': [0.1, 0.5, 0.7, 0.9, 0.95, 0.99,
#                                                1]},
#              scoring='neg_mean_squared_error')

# %%
print(elastic_cv.best_params_)
print(elastic_cv.best_score_)
# Out:
# {'elastic__alpha': 0.0005994842503189409, 'elastic__l1_ratio': 0.9}
# -0.012213675521098371

# %%
    

elastic_estimator = elastic_cv.best_estimator_
elastic_coefs = elastic_estimator['elastic'].coef_
elastic_coefs = pd.DataFrame(elastic_coefs.reshape(1,-1), columns = X.columns)
print_full(elastic_coefs[elastic_coefs != 0].T[0].sort_values(ascending = False))
# Out:
# GrLivArea                0.184505
# OverallQual              0.106670
# Neighborhood_Crawfor     0.105356
# Neighborhood_StoneBr     0.078344
# Exterior1st_BrkFace      0.058058
# Neighborhood_NridgHt     0.054449
# Neighborhood_BrkSide     0.053754
# TotalBsmtSF              0.052408
# SaleType_New             0.043576
# OverallCond              0.040385
# BsmtFinSF1               0.039298
# Condition1_Norm          0.039104
# LotArea                  0.038880
# Neighborhood_NoRidge     0.038591
# GarageCars               0.038550
# Functional               0.033934
# Neighborhood_Somerst     0.027849
# HeatingQC                0.026695
# KitchenQual              0.022908
# MSZoning_FV              0.021737
# LotConfig_CulDSac        0.021552
# BsmtFullBath             0.021489
# BsmtFinType1             0.020700
# HalfBath                 0.018140
# MasVnrType_Stone         0.017377
# FullBath                 0.017303
# TotRmsAbvGrd             0.015734
# WoodDeckSF               0.015631
# MoSold_May               0.013763
# Foundation_PConc         0.013198
# PavedDrive_Y             0.012553
# BsmtExposure             0.012519
# ExterQual                0.012077
# SaleCondition_Normal     0.011033
# GarageQual               0.010327
# BsmtQual                 0.009416
# Neighborhood_ClearCr     0.008957
# ScreenPorch              0.008670
# RoofStyle_Hip            0.006848
# LotConfig_Corner         0.006575
# MoSold_Jun               0.006487
# Exterior1st_MetalSd      0.006188
# BldgType_1Fam            0.005435
# LandContour_HLS          0.004652
# CentralAir_Y             0.004511
# Exterior2nd_Wd Sdng      0.003861
# GarageType_BuiltIn       0.003663
# OpenPorchSF              0.002954
# GarageFinish             0.002850
# EnclosedPorch            0.002163
# MoSold_Jul               0.001683
# 3SsnPorch                0.000838
# BsmtFinSF2               0.000013
# ExterCond               -0.000239
# Neighborhood_CollgCr    -0.000307
# LotShape_IR1            -0.000566
# LandContour_Lvl         -0.000747
# LowQualFinSF            -0.001956
# YrSold                  -0.001960
# BsmtFinType2_BLQ        -0.002188
# Neighborhood_OldTown    -0.002694
# GarageType_Attchd       -0.004076
# Exterior2nd_HdBoard     -0.004077
# BsmtUnfSF               -0.004500
# Condition1_RRAe         -0.005092
# BsmtCond                -0.005851
# Exterior1st_HdBoard     -0.006314
# Neighborhood_Gilbert    -0.006552
# LotConfig_FR2           -0.008989
# HouseStyle_2Story       -0.009279
# Neighborhood_Mitchel    -0.011136
# BedroomAbvGr            -0.011421
# SaleType_COD            -0.011627
# HouseStyle_1.5Fin       -0.012275
# Neighborhood_NWAmes     -0.012446
# Condition1_Artery       -0.014678
# AgeRemodel              -0.016760
# BldgType_Duplex         -0.020050
# SaleType_WD             -0.020140
# Exterior1st_Wd Sdng     -0.020183
# Foundation_BrkTil       -0.021391
# SaleCondition_Family    -0.022708
# Neighborhood_Edwards    -0.023994
# CentralAir_N            -0.032270
# MSZoning_RM             -0.035646
# KitchenAbvGr            -0.057493
# SaleCondition_Abnorml   -0.057541
# Age                     -0.073863
# MSZoning_C (all)        -0.281888
# MoSold_Apr                    NaN
# MoSold_Aug                    NaN
# MoSold_Dec                    NaN
# MoSold_Feb                    NaN
# MoSold_Jan                    NaN
# MoSold_Mar                    NaN
# MoSold_Nov                    NaN
# MoSold_Oct                    NaN
# MoSold_Sep                    NaN
# MSZoning_RH                   NaN
# MSZoning_RL                   NaN
# Street_Grvl                   NaN
# Street_Pave                   NaN
# LotShape_IR2                  NaN
# LotShape_IR3                  NaN
# LotShape_Reg                  NaN
# LandContour_Bnk               NaN
# LandContour_Low               NaN
# Utilities_AllPub              NaN
# Utilities_NoSeWa              NaN
# LotConfig_FR3                 NaN
# LotConfig_Inside              NaN
# LandSlope_Gtl                 NaN
# LandSlope_Mod                 NaN
# LandSlope_Sev                 NaN
# Neighborhood_Blmngtn          NaN
# Neighborhood_Blueste          NaN
# Neighborhood_BrDale           NaN
# Neighborhood_IDOTRR           NaN
# Neighborhood_MeadowV          NaN
# Neighborhood_NAmes            NaN
# Neighborhood_NPkVill          NaN
# Neighborhood_SWISU            NaN
# Neighborhood_Sawyer           NaN
# Neighborhood_SawyerW          NaN
# Neighborhood_Timber           NaN
# Neighborhood_Veenker          NaN
# Condition1_Feedr              NaN
# Condition1_PosA               NaN
# Condition1_PosN               NaN
# Condition1_RRAn               NaN
# Condition1_RRNe               NaN
# Condition1_RRNn               NaN
# Condition2_Artery             NaN
# Condition2_Feedr              NaN
# Condition2_Norm               NaN
# Condition2_PosA               NaN
# Condition2_PosN               NaN
# Condition2_RRAe               NaN
# Condition2_RRAn               NaN
# Condition2_RRNn               NaN
# BldgType_2fmCon               NaN
# BldgType_Twnhs                NaN
# BldgType_TwnhsE               NaN
# HouseStyle_1.5Unf             NaN
# HouseStyle_1Story             NaN
# HouseStyle_2.5Fin             NaN
# HouseStyle_2.5Unf             NaN
# HouseStyle_SFoyer             NaN
# HouseStyle_SLvl               NaN
# RoofStyle_Flat                NaN
# RoofStyle_Gable               NaN
# RoofStyle_Gambrel             NaN
# RoofStyle_Mansard             NaN
# RoofStyle_Shed                NaN
# RoofMatl_CompShg              NaN
# RoofMatl_Membran              NaN
# RoofMatl_Metal                NaN
# RoofMatl_Roll                 NaN
# RoofMatl_Tar&Grv              NaN
# RoofMatl_WdShake              NaN
# RoofMatl_WdShngl              NaN
# Exterior1st_AsbShng           NaN
# Exterior1st_AsphShn           NaN
# Exterior1st_BrkComm           NaN
# Exterior1st_CBlock            NaN
# Exterior1st_CemntBd           NaN
# Exterior1st_ImStucc           NaN
# Exterior1st_Plywood           NaN
# Exterior1st_Stone             NaN
# Exterior1st_Stucco            NaN
# Exterior1st_VinylSd           NaN
# Exterior1st_WdShing           NaN
# Exterior2nd_AsbShng           NaN
# Exterior2nd_AsphShn           NaN
# Exterior2nd_Brk Cmn           NaN
# Exterior2nd_BrkFace           NaN
# Exterior2nd_CBlock            NaN
# Exterior2nd_CmentBd           NaN
# Exterior2nd_ImStucc           NaN
# Exterior2nd_MetalSd           NaN
# Exterior2nd_Other             NaN
# Exterior2nd_Plywood           NaN
# Exterior2nd_Stone             NaN
# Exterior2nd_Stucco            NaN
# Exterior2nd_VinylSd           NaN
# Exterior2nd_Wd Shng           NaN
# MasVnrType_BrkCmn             NaN
# MasVnrType_BrkFace            NaN
# MasVnrType_None               NaN
# Foundation_CBlock             NaN
# Foundation_Slab               NaN
# Foundation_Stone              NaN
# Foundation_Wood               NaN
# BsmtFinType2_ALQ              NaN
# BsmtFinType2_GLQ              NaN
# BsmtFinType2_LwQ              NaN
# BsmtFinType2_Rec              NaN
# BsmtFinType2_Unf              NaN
# Heating_Floor                 NaN
# Heating_GasA                  NaN
# Heating_GasW                  NaN
# Heating_Grav                  NaN
# Heating_OthW                  NaN
# Heating_Wall                  NaN
# Electrical_FuseA              NaN
# Electrical_FuseF              NaN
# Electrical_FuseP              NaN
# Electrical_Mix                NaN
# Electrical_SBrkr              NaN
# GarageType_2Types             NaN
# GarageType_Basment            NaN
# GarageType_CarPort            NaN
# GarageType_Detchd             NaN
# PavedDrive_N                  NaN
# PavedDrive_P                  NaN
# SaleType_CWD                  NaN
# SaleType_Con                  NaN
# SaleType_ConLD                NaN
# SaleType_ConLI                NaN
# SaleType_ConLw                NaN
# SaleType_Oth                  NaN
# SaleCondition_AdjLand         NaN
# SaleCondition_Alloca          NaN
# SaleCondition_Partial         NaN
# BsmtHalfBath                  NaN
# GarageCond                    NaN
# MasVnrArea                    NaN
# 2ndFlrSF                      NaN
# Name: 0, dtype: float64

# %%
non_zero = elastic_coefs.loc[:, (elastic_coefs != 0).any(axis=0)]

X = df[non_zero.columns]
y = (df['SalePrice'])

elastic_pipe = Pipeline([('scale',RobustScaler()),
                              ('elastic',ElasticNet())])
parameters = {'elastic__alpha': np.logspace(-4, -1, 10), 'elastic__l1_ratio': [.1, .5, .7, .9, .95, .99,
1]}

kfolds = KFold(n_splits=10, shuffle=True, random_state=420)

elastic_cv_drop = GridSearchCV(elastic_pipe,parameters,scoring='neg_mean_squared_error',cv=kfolds)
elastic_cv_drop.fit(X,y)
# Out:
# GridSearchCV(cv=KFold(n_splits=10, random_state=420, shuffle=True),
#              estimator=Pipeline(steps=[('scale', RobustScaler()),
#                                        ('elastic', ElasticNet())]),
#              param_grid={'elastic__alpha': array([0.0001    , 0.00021544, 0.00046416, 0.001     , 0.00215443,
#        0.00464159, 0.01      , 0.02154435, 0.04641589, 0.1       ]),
#                          'elastic__l1_ratio': [0.1, 0.5, 0.7, 0.9, 0.95, 0.99,
#                                                1]},
#              scoring='neg_mean_squared_error')

# %%
print(elastic_cv_drop.best_score_)
print(elastic_cv_drop.best_params_)
elastic_estimator_drop = elastic_cv_drop.best_estimator_
elastic_drop_coefs = elastic_estimator_drop['elastic'].coef_
elastic_drop_coefs = pd.DataFrame(elastic_drop_coefs.reshape(1,-1), columns = X.columns)
print_full(elastic_drop_coefs[elastic_drop_coefs != 0].T[0].sort_values(ascending = False))
# Out:
# -0.011898005719748233
# {'elastic__alpha': 0.00046415888336127773, 'elastic__l1_ratio': 0.1}
# GrLivArea                0.183436
# Neighborhood_Crawfor     0.121425
# Neighborhood_StoneBr     0.115211
# OverallQual              0.100347
# Neighborhood_NridgHt     0.071528
# Neighborhood_NoRidge     0.068351
# Neighborhood_BrkSide     0.065888
# Exterior1st_BrkFace      0.058415
# TotalBsmtSF              0.047892
# Neighborhood_ClearCr     0.041303
# OverallCond              0.039447
# LotArea                  0.039114
# Exterior2nd_Wd Sdng      0.037981
# GarageCars               0.037478
# Functional               0.036783
# MSZoning_FV              0.036420
# BsmtFinSF1               0.035049
# Condition1_Norm          0.034855
# LotConfig_CulDSac        0.034251
# Neighborhood_Somerst     0.027547
# HalfBath                 0.027177
# FullBath                 0.026685
# HeatingQC                0.026389
# BsmtFinType1             0.026200
# LandContour_HLS          0.024310
# BsmtFullBath             0.023577
# MasVnrType_Stone         0.023371
# MoSold_May               0.020342
# KitchenQual              0.020263
# TotRmsAbvGrd             0.019964
# CentralAir_Y             0.019407
# PavedDrive_Y             0.019020
# WoodDeckSF               0.017274
# GarageQual               0.012213
# Foundation_PConc         0.012051
# BsmtQual                 0.011945
# BsmtExposure             0.011675
# LotConfig_Corner         0.011078
# BldgType_1Fam            0.010673
# Exterior1st_MetalSd      0.009550
# MoSold_Jun               0.009488
# ExterQual                0.009128
# ScreenPorch              0.008577
# SaleCondition_Normal     0.008536
# RoofStyle_Hip            0.008027
# SaleType_New             0.007435
# OpenPorchSF              0.005596
# MoSold_Jul               0.005535
# LandContour_Lvl          0.003884
# EnclosedPorch            0.002825
# GarageFinish             0.002558
# 3SsnPorch                0.002084
# GarageType_BuiltIn       0.001061
# BsmtFinSF2               0.000315
# Neighborhood_CollgCr    -0.002771
# YrSold                  -0.003718
# LowQualFinSF            -0.003758
# ExterCond               -0.004089
# BsmtUnfSF               -0.005092
# BsmtCond                -0.006667
# Exterior1st_HdBoard     -0.007293
# Neighborhood_OldTown    -0.007587
# Exterior2nd_HdBoard     -0.008771
# LotShape_IR1            -0.008857
# BedroomAbvGr            -0.010977
# GarageType_Attchd       -0.012266
# Neighborhood_Gilbert    -0.015235
# AgeRemodel              -0.018336
# Neighborhood_NWAmes     -0.022991
# Neighborhood_Mitchel    -0.023219
# CentralAir_N            -0.024443
# HouseStyle_1.5Fin       -0.026452
# LotConfig_FR2           -0.029201
# HouseStyle_2Story       -0.029483
# BsmtFinType2_BLQ        -0.030430
# Condition1_Artery       -0.031290
# MSZoning_RM             -0.033806
# Foundation_BrkTil       -0.035745
# BldgType_Duplex         -0.036178
# Neighborhood_Edwards    -0.036966
# Exterior1st_Wd Sdng     -0.054073
# SaleType_WD             -0.055608
# KitchenAbvGr            -0.059007
# SaleCondition_Family    -0.059376
# SaleType_COD            -0.060019
# SaleCondition_Abnorml   -0.062114
# Age                     -0.067283
# Condition1_RRAe         -0.077641
# MSZoning_C (all)        -0.347981
# Name: 0, dtype: float64

# %%
y_hat = elastic_estimator_drop.predict(X)
residuals = y - y_hat

plt.figure(figsize=(10,8))

plt.scatter(y_hat, residuals)


plt.xlabel("predictions", fontsize=16)
plt.ylabel("residuals", fontsize=16)

plt.show()

plt.figure(figsize=(10,8))

plt.scatter(y, y_hat)


plt.xlabel("y", fontsize=16)
plt.ylabel("y_hat", fontsize=16)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ## Interpretability with XGBoost
# We captured the importance of linear features with elasticnet. Now we look for nonlinear feature importance using XGboost

# %%
#We first fit an XGBoost model to the data
kfolds = KFold(n_splits=10, shuffle=True, random_state=69)

X = df.drop(columns = 'SalePrice')
y = (df['SalePrice'])

params = { 'max_depth': [3,6,10],
           'learning_rate': [0.01, 0.05, 0.1],
           'n_estimators': [100, 500, 1000],
           'colsample_bytree': [0.3, 0.7]}
xgbr = xgb.XGBRegressor(seed = 20)
clf = GridSearchCV(estimator=xgbr, 
                   param_grid=params,
                   scoring='neg_mean_squared_error', 
                   verbose=1)
clf.fit(X, y)
print("Best parameters:", clf.best_params_)
print("Lowest RMSE: ", (-clf.best_score_))
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# Best parameters: {'colsample_bytree': 0.3, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 1000}
# Lowest RMSE:  0.01285793541480256
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# Best parameters: {'colsample_bytree': 0.3, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 1000}
# Lowest RMSE:  0.01285793541480256

# %%
xgb_estimator = clf.best_estimator_
xgb_estimator.feature_importances_

xgb_scores = xgb_estimator.feature_importances_
xgb_scores = pd.DataFrame(xgb_scores.reshape(1,-1), columns = X.columns)
print_full(xgb_scores.T[0].sort_values(ascending = False))
# Out:
# GarageCars               0.090241
# OverallQual              0.072068
# ExterQual                0.060280
# GrLivArea                0.049264
# FullBath                 0.043938
# GarageFinish             0.041231
# KitchenQual              0.038553
# BsmtQual                 0.037874
# GarageCond               0.035525
# MSZoning_RL              0.029095
# GarageType_Attchd        0.023993
# CentralAir_N             0.022937
# TotalBsmtSF              0.022912
# Neighborhood_Crawfor     0.012674
# MSZoning_RM              0.012450
# BsmtFinType1             0.010895
# BsmtFinSF1               0.010154
# OverallCond              0.009695
# LotArea                  0.009340
# Exterior1st_BrkComm      0.008675
# AgeRemodel               0.008589
# MSZoning_C (all)         0.008557
# CentralAir_Y             0.008471
# BsmtExposure             0.008456
# SaleCondition_Abnorml    0.008453
# SaleType_New             0.008436
# PavedDrive_Y             0.008366
# Neighborhood_OldTown     0.007813
# GarageQual               0.007659
# Age                      0.007531
# HalfBath                 0.007042
# BldgType_1Fam            0.006887
# PavedDrive_N             0.006562
# Exterior2nd_Brk Cmn      0.006115
# TotRmsAbvGrd             0.006098
# Heating_Grav             0.005329
# Functional               0.005063
# KitchenAbvGr             0.004824
# BsmtFullBath             0.004672
# BsmtFinType2_LwQ         0.004514
# Exterior2nd_Wd Shng      0.004388
# ScreenPorch              0.004388
# OpenPorchSF              0.004088
# Exterior1st_BrkFace      0.003964
# Neighborhood_Sawyer      0.003925
# Exterior1st_AsbShng      0.003850
# LandSlope_Gtl            0.003777
# HeatingQC                0.003745
# BsmtCond                 0.003456
# SaleCondition_Partial    0.003388
# WoodDeckSF               0.003241
# GarageType_Detchd        0.002956
# SaleType_WD              0.002900
# Neighborhood_NWAmes      0.002874
# SaleCondition_Family     0.002776
# RoofStyle_Gambrel        0.002746
# MoSold_Feb               0.002743
# GarageType_2Types        0.002732
# Condition1_PosA          0.002680
# Exterior2nd_AsbShng      0.002598
# BsmtFinType2_Unf         0.002594
# SaleCondition_Normal     0.002587
# Neighborhood_SWISU       0.002568
# GarageType_Basment       0.002553
# RoofStyle_Flat           0.002523
# Exterior1st_VinylSd      0.002414
# MSZoning_FV              0.002358
# Condition1_Artery        0.002327
# Condition2_Feedr         0.002239
# MoSold_Dec               0.002211
# Exterior1st_Plywood      0.002164
# Neighborhood_BrkSide     0.002110
# Condition1_Norm          0.002089
# MSZoning_RH              0.002075
# BedroomAbvGr             0.002040
# LotConfig_CulDSac        0.002001
# Neighborhood_IDOTRR      0.001982
# EnclosedPorch            0.001948
# Neighborhood_Somerst     0.001915
# 2ndFlrSF                 0.001900
# Foundation_BrkTil        0.001897
# Neighborhood_Mitchel     0.001894
# MasVnrArea               0.001854
# YrSold                   0.001833
# MasVnrType_Stone         0.001754
# MoSold_Nov               0.001708
# RoofStyle_Hip            0.001697
# HouseStyle_SLvl          0.001663
# LotShape_Reg             0.001662
# Condition1_RRAe          0.001639
# Exterior1st_HdBoard      0.001587
# LotConfig_FR3            0.001576
# RoofStyle_Gable          0.001552
# BsmtFinSF2               0.001532
# Exterior2nd_MetalSd      0.001510
# Heating_GasA             0.001500
# Neighborhood_ClearCr     0.001483
# Exterior1st_Stucco       0.001464
# Neighborhood_CollgCr     0.001452
# Neighborhood_NAmes       0.001407
# Neighborhood_StoneBr     0.001401
# Exterior2nd_Plywood      0.001400
# Electrical_SBrkr         0.001338
# ExterCond                0.001338
# Exterior2nd_VinylSd      0.001330
# HouseStyle_1.5Fin        0.001290
# Condition1_PosN          0.001289
# Exterior1st_MetalSd      0.001287
# Condition2_Norm          0.001284
# Exterior2nd_Stucco       0.001269
# BsmtUnfSF                0.001243
# Neighborhood_Blmngtn     0.001218
# MoSold_Apr               0.001212
# HouseStyle_1Story        0.001145
# SaleType_ConLD           0.001128
# Neighborhood_Edwards     0.001107
# RoofMatl_Tar&Grv         0.001103
# BsmtFinType2_BLQ         0.001101
# MasVnrType_BrkFace       0.001098
# Electrical_FuseF         0.001090
# MasVnrType_None          0.001087
# Neighborhood_NridgHt     0.001061
# RoofMatl_WdShngl         0.001054
# Foundation_Slab          0.001048
# SaleCondition_Alloca     0.001032
# Neighborhood_Gilbert     0.001029
# BldgType_2fmCon          0.000998
# LandContour_Low          0.000997
# Electrical_FuseA         0.000992
# LandContour_Lvl          0.000990
# MoSold_Jan               0.000980
# GarageType_CarPort       0.000980
# MoSold_Aug               0.000978
# Exterior2nd_BrkFace      0.000976
# Exterior1st_Wd Sdng      0.000974
# Foundation_Wood          0.000962
# Neighborhood_MeadowV     0.000956
# SaleType_COD             0.000926
# MoSold_Sep               0.000926
# BsmtFinType2_Rec         0.000915
# LotConfig_FR2            0.000912
# Exterior2nd_CmentBd      0.000860
# GarageType_BuiltIn       0.000823
# SaleType_Oth             0.000823
# LotShape_IR1             0.000801
# LandContour_HLS          0.000797
# BldgType_Twnhs           0.000791
# Exterior2nd_AsphShn      0.000791
# Condition1_Feedr         0.000786
# LotConfig_Inside         0.000779
# LowQualFinSF             0.000767
# Foundation_CBlock        0.000744
# HouseStyle_2Story        0.000738
# MoSold_Mar               0.000738
# Neighborhood_Timber      0.000732
# Foundation_PConc         0.000732
# SaleType_ConLI           0.000714
# SaleType_CWD             0.000710
# PavedDrive_P             0.000705
# BldgType_Duplex          0.000699
# MoSold_May               0.000679
# LotConfig_Corner         0.000678
# LandContour_Bnk          0.000667
# Neighborhood_BrDale      0.000656
# LotShape_IR2             0.000645
# BsmtHalfBath             0.000617
# BsmtFinType2_ALQ         0.000611
# Exterior2nd_Wd Sdng      0.000580
# Heating_GasW             0.000574
# MoSold_Jul               0.000566
# BldgType_TwnhsE          0.000541
# LandSlope_Mod            0.000521
# Exterior2nd_HdBoard      0.000516
# Neighborhood_SawyerW     0.000514
# MoSold_Jun               0.000498
# LandSlope_Sev            0.000495
# MasVnrType_BrkCmn        0.000448
# MoSold_Oct               0.000415
# Neighborhood_NoRidge     0.000398
# HouseStyle_1.5Unf        0.000376
# 3SsnPorch                0.000376
# Foundation_Stone         0.000372
# Exterior1st_WdShing      0.000352
# Exterior1st_CemntBd      0.000351
# SaleType_ConLw           0.000303
# Street_Grvl              0.000220
# Neighborhood_Veenker     0.000216
# Street_Pave              0.000207
# HouseStyle_SFoyer        0.000200
# Exterior2nd_ImStucc      0.000164
# Condition2_PosN          0.000136
# Exterior2nd_Other        0.000135
# Condition2_PosA          0.000105
# LotShape_IR3             0.000076
# RoofMatl_CompShg         0.000055
# HouseStyle_2.5Unf        0.000032
# Condition2_RRNn          0.000024
# Electrical_Mix           0.000000
# RoofStyle_Shed           0.000000
# HouseStyle_2.5Fin        0.000000
# RoofStyle_Mansard        0.000000
# Condition1_RRAn          0.000000
# Condition1_RRNe          0.000000
# Condition2_RRAn          0.000000
# Condition2_RRAe          0.000000
# RoofMatl_Membran         0.000000
# Exterior1st_CBlock       0.000000
# RoofMatl_Metal           0.000000
# Neighborhood_Blueste     0.000000
# SaleType_Con             0.000000
# Neighborhood_NPkVill     0.000000
# Heating_Wall             0.000000
# Heating_OthW             0.000000
# Heating_Floor            0.000000
# Condition1_RRNn          0.000000
# SaleCondition_AdjLand    0.000000
# BsmtFinType2_GLQ         0.000000
# Exterior2nd_Stone        0.000000
# RoofMatl_Roll            0.000000
# Exterior2nd_CBlock       0.000000
# Exterior1st_Stone        0.000000
# Utilities_NoSeWa         0.000000
# Utilities_AllPub         0.000000
# Exterior1st_ImStucc      0.000000
# Electrical_FuseP         0.000000
# Exterior1st_AsphShn      0.000000
# RoofMatl_WdShake         0.000000
# Condition2_Artery        0.000000
# Name: 0, dtype: float32

# %%
# Let's do a quick graph of the highest feature importance
ordered = xgb_scores.sort_values(by = 0, axis = 1, ascending = False)

# fig, ax = plt.subplots(2, figsize=(10, 6))

# ax[0].scatter(x = df[ordered.columns[0]],y = df['SalePrice'])
# ax[0].set_xlabel(ordered.columns[0])
# ax[0].set_ylabel('Log Sale Price')
# plt.show()
for i in range(10):
    plt.scatter(x = df[ordered.columns[i]],y = df['SalePrice'])
    plt.xlabel(ordered.columns[i])
    plt.ylabel("Sale Price")
    plt.show()

# %% [markdown]
# It doesn't seem like we gain much interpretability from fitting an XGBoost model. Probably better for prediction.
