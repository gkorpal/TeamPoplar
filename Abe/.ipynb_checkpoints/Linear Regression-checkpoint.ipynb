# %%
# %matplotlib notebook
# We start off with the baseline import statements we need to do the basic data manipulation and visualization.
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib.pyplot as plt
import calendar
from sklearn.ensemble import RandomForestClassifier

sns.set_style("whitegrid")

#We create and set aside a copy of the data for initial exploration
housing_train = pd.read_csv('../data/train.csv')
housing = housing_train.copy()

#MISSING DATA
total = housing.isnull().sum().sort_values(ascending=False)
percent = (housing.isnull().sum()/housing.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])

#CORRELATION CHECK
corr_matrix = housing.corr()
top_corr = corr_matrix['SalePrice'].sort_values(ascending = False)

top_corr
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# Id              -0.021917
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# MSSubClass      -0.084284
# EnclosedPorch   -0.128578
# KitchenAbvGr    -0.135907
# Name: SalePrice, dtype: float64

# %%
#DROPPING SOME COLUMNS
drop = ['PoolQC', 'PoolArea','MiscFeature', 'MiscVal', 'Alley', 'Fence', 'FireplaceQu', 'Fireplaces', 'LotFrontage']
drop2 = ['Id','GarageArea','1stFlrSF','GarageYrBlt','MSSubClass','BsmtFinSF2'] 
#dropped MSSubclass and BsmtFinSF2 and RoofMatl and Exterior2nd, and Condition2 for collinearity reasons
housing.drop(columns = drop + drop2, inplace = True)
housing['Age'] = housing['YrSold'] - housing['YearBuilt']
housing['AgeRemodel'] = housing['YrSold'] - housing['YearRemodAdd']
housing = housing[housing.AgeRemodel >= 0]
housing = housing[housing.GrLivArea < 4000]
housing.drop(columns = ['YearBuilt','YearRemodAdd'], inplace = True)

housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1456 entries, 0 to 1459
# Data columns (total 66 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSZoning       1456 non-null   object
#  1   LotArea        1456 non-null   int64
#  2   Street         1456 non-null   object
#  3   LotShape       1456 non-null   object
#  4   LandContour    1456 non-null   object
#  5   Utilities      1456 non-null   object
#  6   LotConfig      1456 non-null   object
#  7   LandSlope      1456 non-null   object
#  8   Neighborhood   1456 non-null   object
#  9   Condition1     1456 non-null   object
#  10  Condition2     1456 non-null   object
#  11  BldgType       1456 non-null   object
#  12  HouseStyle     1456 non-null   object
#  13  OverallQual    1456 non-null   int64
#  14  OverallCond    1456 non-null   int64
#  15  RoofStyle      1456 non-null   object
#  16  RoofMatl       1456 non-null   object
#  17  Exterior1st    1456 non-null   object
#  18  Exterior2nd    1456 non-null   object
#  19  MasVnrType     1448 non-null   object
#  20  MasVnrArea     1448 non-null   float64
#  21  ExterQual      1456 non-null   object
#  22  ExterCond      1456 non-null   object
#  23  Foundation     1456 non-null   object
#  24  BsmtQual       1419 non-null   object
#  25  BsmtCond       1419 non-null   object
#  26  BsmtExposure   1418 non-null   object
#  27  BsmtFinType1   1419 non-null   object
#  28  BsmtFinSF1     1456 non-null   int64
#  29  BsmtFinType2   1418 non-null   object
#  30  BsmtUnfSF      1456 non-null   int64
#  31  TotalBsmtSF    1456 non-null   int64
#  32  Heating        1456 non-null   object
#  33  HeatingQC      1456 non-null   object
#  34  CentralAir     1456 non-null   object
#  35  Electrical     1455 non-null   object
#  36  2ndFlrSF       1456 non-null   int64
#  37  LowQualFinSF   1456 non-null   int64
#  38  GrLivArea      1456 non-null   int64
#  39  BsmtFullBath   1456 non-null   int64
#  40  BsmtHalfBath   1456 non-null   int64
#  41  FullBath       1456 non-null   int64
#  42  HalfBath       1456 non-null   int64
#  43  BedroomAbvGr   1456 non-null   int64
#  44  KitchenAbvGr   1456 non-null   int64
#  45  KitchenQual    1456 non-null   object
#  46  TotRmsAbvGrd   1456 non-null   int64
#  47  Functional     1456 non-null   object
#  48  GarageType     1375 non-null   object
#  49  GarageFinish   1375 non-null   object
#  50  GarageCars     1456 non-null   int64
#  51  GarageQual     1375 non-null   object
#  52  GarageCond     1375 non-null   object
#  53  PavedDrive     1456 non-null   object
#  54  WoodDeckSF     1456 non-null   int64
#  55  OpenPorchSF    1456 non-null   int64
#  56  EnclosedPorch  1456 non-null   int64
#  57  3SsnPorch      1456 non-null   int64
#  58  ScreenPorch    1456 non-null   int64
#  59  MoSold         1456 non-null   int64
#  60  YrSold         1456 non-null   int64
#  61  SaleType       1456 non-null   object
#  62  SaleCondition  1456 non-null   object
#  63  SalePrice      1456 non-null   int64
#  64  Age            1456 non-null   int64
#  65  AgeRemodel     1456 non-null   int64
# dtypes: float64(1), int64(27), object(38)
# memory usage: 762.1+ KB

# %%
#FURTHER DATA CLEANING
housing_cat = housing.select_dtypes(exclude=[np.number])
housing_numeric = housing.select_dtypes(include=[np.number])

#Numeric
numeric_unbounded = ['LotArea', 'MasVnrArea','BsmtFinSF1', 'BsmtUnfSF',
                     'TotalBsmtSF','2ndFlrSF','LowQualFinSF','GrLivArea','WoodDeckSF',
                     'OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch', 'SalePrice',
                     'Age','AgeRemodel']

#numeric_one_hot = ['MSSubClass','MoSold']
numeric_one_hot = ['MoSold']
numeric_ordinal = [x for x in housing_numeric.columns 
                   if (x not in numeric_unbounded and x not in numeric_one_hot)]

housing_numeric_unbounded = housing_numeric[numeric_unbounded]
#housing_numeric_unbounded['MasVnrArea'] = housing_numeric_unbounded['MasVnrArea'].fillna(0)
housing_numeric_one_hot = housing_numeric[numeric_one_hot]
housing_numeric_ordinal = housing_numeric[numeric_ordinal]

#housing_numeric_one_hot['MSSubClass'] = housing_numeric_one_hot['MSSubClass'].astype('str')
housing_numeric_one_hot['MoSold'] = housing_numeric_one_hot['MoSold'].replace({i:calendar.month_name[i][:3] for i in range(1,13)})
housing_numeric_one_hot = pd.get_dummies(housing_numeric_one_hot)
#Categorical
cat_ordinal = ['ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
               'BsmtFinType1', 'HeatingQC', 'KitchenQual','Functional','GarageFinish',
               'GarageQual', 'GarageCond']

housing_cat_ordinal = housing_cat[cat_ordinal]
housing_cat_ordinal.fillna('No', inplace = True)
housing_cat_one_hot = housing_cat.drop(columns = cat_ordinal)

housing_cat_one_hot = pd.get_dummies(housing_cat_one_hot)
#housing_cat_one_hot = housing_cat_one_hot.drop(columns = 'Exterior2nd_CBlock')

def mapper(cat):
    if cat in ['ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond', 'GarageQual', 'GarageCond',
               'HeatingQC', 'KitchenQual']:
        mapper = {'No':0, 'Po':1, 'Fa':2,'TA':3,'Gd':4,'Ex':5}
    elif cat == 'BsmtExposure':
            mapper = {'No':0,'No':1, 'Mn':2, 'Av':3,'Gd':4}
    elif cat == 'BsmtFinType1':
        mapper = {'No':0,'Unf':1,'LwQ':2,'Rec':3,'BLQ':4,'ALQ':5,'GLQ':6}
    elif cat == 'Functional':
        mapper = {'Sal':0,'Sev':1,'Maj2':2,'Maj1':3,'Mod':4,'Min2':5, 'Min1':6,'Typ':7}
    else:
        mapper = {'No':0,'Unf':1,'RFn':2,'Fin':3}
        
    return mapper

for cat in cat_ordinal:
    housing_cat_ordinal[cat].replace(mapper(cat), inplace = True)

#Combining numeric and categorical
housing_ordinal = pd.concat([housing_numeric_ordinal,housing_cat_ordinal], axis = 'columns')
housing_one_hot = pd.concat([housing_numeric_one_hot, housing_cat_one_hot], axis = 'columns')
housing_clean = pd.concat([housing_one_hot, housing_ordinal, housing_numeric_unbounded], 
                          axis = 'columns')

#MORE CORRELATION
ordinal_prices = pd.concat([housing_ordinal, housing['SalePrice']], axis = 'columns')
ordinal_corr_matrix = ordinal_prices.corr()
top_corr_ordinal = ordinal_corr_matrix['SalePrice'].sort_values(ascending = False)

one_hot_prices = pd.concat([housing_one_hot, housing['SalePrice']], axis = 'columns')
one_hot_corr_matrix = one_hot_prices.corr()
top_corr_one_hot = one_hot_corr_matrix['SalePrice'].filter(like = 'Neighborhood').sort_values(ascending = False)
# Out:
# <ipython-input-3-0480b75de7f2>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_numeric_one_hot['MoSold'] = housing_numeric_one_hot['MoSold'].replace({i:calendar.month_name[i][:3] for i in range(1,13)})
# C:\Users\abrah\anaconda3\lib\site-packages\pandas\core\frame.py:4462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
# C:\Users\abrah\anaconda3\lib\site-packages\pandas\core\series.py:4509: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
#REMOVAL OF THE REMAINING NaN
housing_clean.isnull().sum().sort_values(ascending=False)
df = housing_clean.copy()
problem_col = df.isin([np.nan, np.inf, -np.inf]).sum(axis=0)[df.isin([np.nan, np.inf, -np.inf]).sum(axis=0) != 0] 
index_to_drop = df[problem_col.index[0]][df[problem_col.index[0]].isin([np.nan, np.inf, -np.inf])].index
df.drop(index = index_to_drop, inplace = True)
df.isnull().sum().sort_values(ascending=False)
# Out:
# MoSold_Apr          0
# Foundation_Slab     0
# Foundation_Wood     0
# BsmtFinType2_ALQ    0
# BsmtFinType2_BLQ    0
#                    ..
# BldgType_1Fam       0
# BldgType_2fmCon     0
# BldgType_Duplex     0
# BldgType_Twnhs      0
# AgeRemodel          0
# Length: 228, dtype: int64

# %%
#RANDOM FOREST FOR FEATURE IMPORTANCE
X_train = df.drop(columns = ['SalePrice'])
y_train = df['SalePrice']

forest = RandomForestClassifier(n_estimators=500, max_depth=4)

forest.fit(X_train, y_train)

forest.feature_importances_
score_df = pd.DataFrame({'feature':X_train.columns,
                            'importance_score': forest.feature_importances_})

# %%
#We will look at feature importances and their correlation with the 'SalePrice'
score_df.sort_values('feature', inplace=True)
top_corr = df.corr()['SalePrice'].abs().drop(index = ['SalePrice']) #I suppose we want to look at the absolute value
                                                                    #of the correlation. Is that right?
top_corr.sort_index(inplace=True) 
#now rows of score_df and top_corr match and we can add the values of correlation
score_df['correlation'] = top_corr.values

# %%
score_df.sort_values(ascending=False, by = ['importance_score'], inplace = True)
score_df['importance_score_rank'] = [k for k in range(1,1+len(score_df.index))]
score_df.sort_values(ascending=False, by = ['correlation'], inplace = True)
score_df['correlation_rank'] = [k for k in range(1,1+len(score_df.index))]
score_df['overall_rank'] = (score_df['importance_score_rank'] + score_df['correlation_rank'])/2 
score_df.sort_values(ascending=True, by = ['overall_rank'], inplace = True)
score_df.reset_index(drop = True, inplace = True)
score_df.head(20)
# Out:
#              feature  importance_score  correlation  importance_score_rank  \
# 0        OverallQual          0.029290     0.799918                      2
# 1          GrLivArea          0.030474     0.722139                      1
# 2        TotalBsmtSF          0.027201     0.646185                      3
# 3                Age          0.026902     0.535463                      4
# 4         GarageCars          0.017925     0.648633                     12
# 5          ExterQual          0.015932     0.693160                     16
# 6           FullBath          0.019813     0.560927                     11
# 7        KitchenQual          0.014643     0.665065                     17
# 8         MasVnrArea          0.019965     0.478862                      9
# 9         AgeRemodel          0.017396     0.523089                     13
# 10      TotRmsAbvGrd          0.015974     0.540229                     15
# 11      GarageFinish          0.014302     0.556563                     18
# 12        BsmtFinSF1          0.019908     0.393261                     10
# 13          BsmtQual          0.012742     0.591088                     22
# 14       OpenPorchSF          0.021273     0.325635                      7
# 15          2ndFlrSF          0.022506     0.300659                      6
# 16         HeatingQC          0.009792     0.435113                     26
# 17           LotArea          0.026404     0.270776                      5
# 18        WoodDeckSF          0.016817     0.322812                     14
# 19  Foundation_PConc          0.004725     0.505645                     40
#
#     correlation_rank  overall_rank
# 0                  1           1.5
# 1                  2           1.5
# 2                  6           4.5
# 3                 11           7.5
# 4                  5           8.5
# 5                  3           9.5
# 6                  8           9.5
# 7                  4          10.5
# 8                 14          11.5
# 9                 12          12.5
# 10                10          12.5
# 11                 9          13.5
# 12                17          13.5
# 13                 7          14.5
# 14                26          16.5
# 15                31          18.5
# 16                15          20.5
# 17                36          20.5
# 18                28          21.0
# 19                13          26.5

# %% [markdown]
# Correlation measures only linear dependence between variables and it does not detect non-linear dependence (in particular cor(X,Y) can be 0 for random variables X and Y=X^2, which are of course completely dependent). So, if a given feature has high feature_importance score, but low correlation it means that 'SalePrice' depend on it in a non-linear manner.

# %%
plt.figure(figsize=(7, 7))
plt.scatter(score_df['importance_score_rank'][:20], score_df['correlation_rank'][:20], c ="blue",
            linewidths = 1)
plt.title('importance_rank vs correlation_rank')
plt.xticks(np.arange(0, 40, step=1))
plt.yticks(np.arange(0, 40, step=1))
plt.xlabel("importance_score_rank")
plt.ylabel("correlation_rank")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %% [markdown]
# ## Using Linear Regression models to predict housing prices
# Below, we compare several candidate models to predict the housing prices. We will compare the baselined model of sale price average along with ordinary least squares, ridge regression, lasso regression, and elastic net regression. We will be operating with log housing prices to combat heteroscedasticity.

# %% [markdown]
# ### Ordinary Least Squares Regression Coefficients blow up due to collinearity in categorical data
# One weird thing is that the ordinary Least Squares Regression Coefficients are on radically different scales from one another. We see very negative coefficients along with very large positive coefficients. We make some plots of the scales of the regression coefficients below. We notice that the scales of the categorical variables seem to be much greater than those of the unbounded or the ordinal variables. Ordinary Least Squares is ill fit to deal with the multicollinearity of these categorical variables. This is taken care of via regularization which limits the size of the coefficients. We'll describe regularization later. OLS blowup can be mitigated by dummy encoding the variables instead of one-hot but I was still having collinearity problems on cross validation for the dummy encoding.

# %%
#We scale all the data note X_train and y_train are fairly clean
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.model_selection import train_test_split
X = df.drop(columns = 'SalePrice')
y = np.log(df['SalePrice'])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 20)

#We call the standard Scaler object and fit it
scaler = StandardScaler()
scaler.fit(X_train)


#We work with the scaled training set and log prices
X_train = (scaler.transform(X_train))
X_test = (scaler.transform(X_test))

# %%
#Our baseline model looking at the average
y_pred_average = np.ones(len(y_test)) * np.mean(y_train)

# %%
#Our Simple Linear Regression Model
from sklearn.linear_model import LinearRegression
slr = LinearRegression(copy_X = True)
slr.fit(X_train, y_train)
y_pred_slr = (slr.predict(X_test))

# %%
#Comparison of the RMSE. It is huge on the new data but relatively good on the training set suggesting overfit
from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred_average, squared = False))
print(mean_squared_error(y_train, (slr.predict(X_train)), squared = False))

print(mean_squared_error((y_test), (y_pred_slr), squared = False))
# Out:
# 0.3930635491149113
# 0.09475578957951465
# 2976656824866.3867

# %% [markdown]
# Here we record some of the blow up of the coefficients

# %%
#Dataframe showing which coefficients correspond
print('Linear Regression Coefficients')
slr_coefficients = pd.DataFrame(slr.coef_.reshape(1,-1), columns = X.columns)
def print_full(x):
    pd.set_option('display.max_rows', len(x))
    print(x)
    pd.reset_option('display.max_rows')
print_full(slr_coefficients.T[0].sort_values(ascending = False))
# Out:
# Linear Regression Coefficients
# LandSlope_Gtl            2.461290e+12
# LandSlope_Mod            2.304593e+12
# RoofMatl_CompShg         1.596963e+12
# Exterior1st_AsphShn      1.272292e+12
# Condition2_RRAe          1.116769e+12
# RoofMatl_Tar&Grv         1.061049e+12
# Utilities_AllPub         1.043001e+12
# LandSlope_Sev            9.076213e+11
# MSZoning_RL              9.022694e+11
# RoofMatl_WdShake         8.976408e+11
# Condition2_PosN          8.033266e+11
# MSZoning_RM              7.936206e+11
# HouseStyle_1Story        7.658979e+11
# Heating_GasA             7.435379e+11
# Electrical_SBrkr         7.044554e+11
# HouseStyle_2Story        6.994521e+11
# RoofMatl_WdShngl         6.959990e+11
# Electrical_FuseA         6.153389e+11
# Heating_GasW             5.680196e+11
# PavedDrive_Y             5.471451e+11
# HouseStyle_1.5Fin        4.708782e+11
# PavedDrive_N             4.701992e+11
# SaleType_Con             4.485164e+11
# MSZoning_FV              4.355931e+11
# RoofMatl_Roll            4.022329e+11
# Electrical_FuseF         3.444459e+11
# HouseStyle_SLvl          3.222479e+11
# LandContour_Lvl          3.146705e+11
# RoofMatl_Metal           3.011687e+11
# Heating_Wall             2.978204e+11
# Heating_Grav             2.978204e+11
# PavedDrive_P             2.974156e+11
# LotShape_Reg             2.551180e+11
# Exterior2nd_VinylSd      2.500159e+11
# LotShape_IR1             2.492820e+11
# MSZoning_RH              2.391463e+11
# HouseStyle_SFoyer        2.282097e+11
# Neighborhood_NAmes       2.271440e+11
# LandContour_Bnk          2.199552e+11
# Exterior2nd_MetalSd      1.926188e+11
# Exterior2nd_HdBoard      1.881435e+11
# Neighborhood_CollgCr     1.857814e+11
# MSZoning_C (all)         1.831066e+11
# LandContour_HLS          1.828969e+11
# Exterior2nd_Wd Sdng      1.773539e+11
# Heating_OthW             1.721168e+11
# Heating_Floor            1.721168e+11
# Neighborhood_OldTown     1.689341e+11
# Foundation_PConc         1.573072e+11
# Foundation_CBlock        1.565510e+11
# LandContour_Low          1.557680e+11
# Exterior2nd_Plywood      1.550242e+11
# Neighborhood_Edwards     1.547925e+11
# HouseStyle_1.5Unf        1.514618e+11
# Neighborhood_Somerst     1.458703e+11
# Neighborhood_Gilbert     1.399178e+11
# Neighborhood_NridgHt     1.386885e+11
# Neighborhood_Sawyer      1.386885e+11
# Neighborhood_NWAmes      1.336298e+11
# Neighborhood_BrkSide     1.255703e+11
# Neighborhood_SawyerW     1.227416e+11
# HouseStyle_2.5Unf        1.175555e+11
# Neighborhood_Crawfor     1.137549e+11
# Neighborhood_Mitchel     1.121754e+11
# Electrical_FuseP         1.099061e+11
# HouseStyle_2.5Fin        1.073663e+11
# Neighborhood_NoRidge     1.055855e+11
# Exterior1st_CBlock       1.017628e+11
# Exterior2nd_CmentBd      1.001060e+11
# Neighborhood_Timber      9.849452e+10
# Neighborhood_IDOTRR      9.663074e+10
# Foundation_BrkTil        9.563949e+10
# LotShape_IR2             9.002970e+10
# Neighborhood_StoneBr     8.228385e+10
# Neighborhood_SWISU       8.228385e+10
# Electrical_Mix           7.775380e+10
# Neighborhood_ClearCr     7.765589e+10
# Exterior2nd_Wd Shng      7.506394e+10
# Exterior2nd_Stucco       7.506394e+10
# Exterior2nd_BrkFace      7.147199e+10
# Neighborhood_BrDale      7.010331e+10
# Neighborhood_Blmngtn     6.455012e+10
# Neighborhood_MeadowV     6.455012e+10
# Neighborhood_Veenker     5.844602e+10
# Exterior2nd_AsbShng      5.208544e+10
# Neighborhood_NPkVill     4.779222e+10
# Foundation_Slab          4.180669e+10
# Exterior2nd_ImStucc      3.692165e+10
# LotShape_IR3             3.330612e+10
# Exterior2nd_Brk Cmn      3.304011e+10
# Exterior2nd_Stone        2.862775e+10
# Foundation_Stone         2.217753e+10
# Neighborhood_Blueste     1.955947e+10
# Exterior2nd_Other        1.654459e+10
# Foundation_Wood          1.404716e+10
# MoSold_Jun               1.233363e+08
# MoSold_Jul               1.198287e+08
# MoSold_May               1.131096e+08
# MoSold_Apr               9.371615e+07
# MoSold_Mar               8.788510e+07
# MoSold_Aug               8.685835e+07
# MoSold_Oct               8.145378e+07
# MoSold_Nov               7.426640e+07
# MoSold_Sep               6.893912e+07
# MoSold_Jan               6.607670e+07
# MoSold_Dec               6.382851e+07
# MoSold_Feb               6.382851e+07
# GrLivArea                1.339661e-01
# OverallQual              5.454913e-02
# OverallCond              4.503229e-02
# TotalBsmtSF              4.163175e-02
# GarageQual               3.415274e-02
# LotArea                  3.005087e-02
# GarageCars               2.432767e-02
# ScreenPorch              2.074089e-02
# BsmtFinSF1               1.967979e-02
# BsmtFullBath             1.937374e-02
# Functional               1.853413e-02
# KitchenQual              1.554878e-02
# HeatingQC                1.508316e-02
# HalfBath                 1.468403e-02
# FullBath                 1.215340e-02
# TotRmsAbvGrd             1.156177e-02
# WoodDeckSF               1.071238e-02
# BsmtExposure             9.342595e-03
# BsmtQual                 7.908186e-03
# EnclosedPorch            5.597240e-03
# GarageFinish             5.369084e-03
# BsmtFinType1             5.242374e-03
# OpenPorchSF              4.976919e-03
# BsmtHalfBath             4.531454e-03
# MasVnrArea               4.201066e-03
# BsmtFinType2_GLQ         4.004346e-03
# 3SsnPorch                3.048576e-03
# YrSold                   2.017250e-03
# BsmtFinType2_ALQ         8.702176e-04
# ExterQual                7.317811e-04
# GarageCond              -3.614854e-04
# BsmtCond                -1.597980e-03
# BsmtFinType2_LwQ        -2.287574e-03
# LowQualFinSF            -3.631386e-03
# BsmtUnfSF               -4.016554e-03
# BsmtFinType2_Unf        -5.478546e-03
# BedroomAbvGr            -6.067377e-03
# BsmtFinType2_Rec        -6.278681e-03
# AgeRemodel              -7.371364e-03
# BsmtFinType2_BLQ        -7.734813e-03
# ExterCond               -8.398251e-03
# GarageType_CarPort      -8.817215e-03
# GarageType_Basment      -8.912824e-03
# GarageType_2Types       -1.299544e-02
# 2ndFlrSF                -1.602879e-02
# KitchenAbvGr            -1.649915e-02
# GarageType_BuiltIn      -2.053735e-02
# GarageType_Detchd       -3.927320e-02
# GarageType_Attchd       -4.123403e-02
# Age                     -5.645660e-02
# SaleCondition_AdjLand   -6.715142e+09
# SaleCondition_Alloca    -1.093860e+10
# Exterior1st_BrkComm     -1.362114e+10
# Exterior1st_ImStucc     -1.362114e+10
# SaleCondition_Family    -1.390931e+10
# SaleType_ConLw          -1.413497e+10
# SaleType_Oth            -1.730317e+10
# SaleType_CWD            -1.730317e+10
# Exterior1st_Stone       -1.925368e+10
# SaleType_ConLI          -1.997008e+10
# SaleType_ConLD          -2.443400e+10
# SaleCondition_Abnorml   -3.275044e+10
# SaleCondition_Partial   -3.351848e+10
# Condition1_RRNe         -3.925081e+10
# Exterior1st_AsbShng     -4.692787e+10
# Exterior1st_WdShing     -4.692787e+10
# SaleCondition_Normal    -4.744278e+10
# SaleType_COD            -5.220372e+10
# Condition1_RRNn         -5.545410e+10
# RoofStyle_Shed          -6.178312e+10
# Exterior1st_Stucco      -6.180003e+10
# Condition1_PosA         -6.784977e+10
# Condition1_RRAe         -6.784977e+10
# LotConfig_FR3           -7.422653e+10
# Exterior1st_BrkFace     -7.811851e+10
# Exterior1st_CemntBd     -8.345166e+10
# SaleType_New            -8.538691e+10
# Condition1_PosN         -9.164067e+10
# Exterior2nd_CBlock      -9.883938e+10
# MasVnrType_BrkCmn       -1.018712e+11
# SaleType_WD             -1.047287e+11
# RoofStyle_Mansard       -1.069057e+11
# Exterior1st_Plywood     -1.142615e+11
# RoofMatl_Membran        -1.164649e+11
# Condition1_RRAn         -1.199577e+11
# BldgType_2fmCon         -1.341408e+11
# Exterior1st_Wd Sdng     -1.492404e+11
# BldgType_Twnhs          -1.534050e+11
# Exterior1st_HdBoard     -1.573746e+11
# Exterior1st_MetalSd     -1.589811e+11
# Condition1_Artery       -1.592534e+11
# RoofStyle_Flat          -1.629775e+11
# RoofStyle_Gambrel       -1.846153e+11
# BldgType_Duplex         -1.902404e+11
# Condition1_Feedr        -2.037626e+11
# Exterior1st_VinylSd     -2.068081e+11
# LotConfig_FR2           -2.131643e+11
# Condition2_PosA         -2.574447e+11
# Condition2_RRAn         -2.574447e+11
# BldgType_TwnhsE         -2.696949e+11
# LotConfig_CulDSac       -2.900310e+11
# MasVnrType_Stone        -3.003892e+11
# Condition1_Norm         -3.042434e+11
# CentralAir_Y            -3.260789e+11
# CentralAir_N            -3.260789e+11
# Condition2_RRNn         -3.639019e+11
# Condition2_Artery       -3.639019e+11
# BldgType_1Fam           -3.651160e+11
# LotConfig_Corner        -4.684484e+11
# Utilities_NoSeWa        -4.690532e+11
# MasVnrType_BrkFace      -4.708953e+11
# MasVnrType_None         -5.049617e+11
# LotConfig_Inside        -5.403672e+11
# Condition2_Feedr        -6.290485e+11
# RoofStyle_Hip           -7.961241e+11
# RoofStyle_Gable         -8.229158e+11
# Condition2_Norm         -8.869546e+11
# Street_Pave             -1.111126e+12
# Street_Grvl             -1.111126e+12
# Exterior2nd_AsphShn     -1.269368e+12
# Name: 0, dtype: float64

# %%
# A plot of the scales of the linear regression coefficients.
log_slr_coef = np.log10(np.abs(slr.coef_))

fig, ax = plt.subplots()
sns.scatterplot(data = log_slr_coef)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Plots of the unbounded and ordinal variable coefficient scales
numeric_train_unbounded = [x for x in numeric_unbounded if x != 'SalePrice']
log_coefs = np.log10(np.abs(slr_coefficients))
fig, ax = plt.subplots()
sns.scatterplot(data = log_coefs[numeric_train_unbounded])
fig, ax = plt.subplots()
sns.scatterplot(data = log_coefs[numeric_ordinal + cat_ordinal])
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %% [markdown]
# # Ordinary least squares on the numerical data
# Instead we look at an OLS baseline for the numerical data, excluding the categorical variables.

# %%
X = df.drop(columns = 'SalePrice')
y = np.log(df['SalePrice'])
numeric_train_unbounded = [x for x in numeric_unbounded if x!= 'SalePrice']
numeric_train = numeric_train_unbounded + numeric_ordinal + cat_ordinal

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 20)

#We call the standard Scaler object and fit it
X_train = X_train[numeric_train]
scaler = StandardScaler()
scaler.fit_transform(X_train)

slr = LinearRegression(copy_X = True)
slr.fit(X_train, y_train)
y_pred_slr = (slr.predict(X_train))

# %%
slr_coefficients = pd.DataFrame(slr.coef_.reshape(1,-1), columns = X_train.columns)
def print_full(x):
    pd.set_option('display.max_rows', len(x))
    print(x)
    pd.reset_option('display.max_rows')
print_full(slr_coefficients.T[0].sort_values(ascending = False))
# Out:
# OverallQual      0.054296
# OverallCond      0.052404
# GarageCars       0.036872
# Functional       0.033740
# BsmtFullBath     0.032515
# KitchenQual      0.030234
# HalfBath         0.029475
# ExterQual        0.022655
# HeatingQC        0.022483
# FullBath         0.016400
# GarageQual       0.015682
# TotRmsAbvGrd     0.012228
# BsmtHalfBath     0.009821
# GarageCond       0.009785
# BsmtExposure     0.008323
# BsmtQual         0.007484
# GarageFinish     0.005089
# ScreenPorch      0.000353
# GrLivArea        0.000308
# TotalBsmtSF      0.000141
# EnclosedPorch    0.000106
# BsmtFinType1     0.000085
# BsmtFinSF1       0.000042
# WoodDeckSF       0.000039
# MasVnrArea       0.000009
# LotArea          0.000004
# OpenPorchSF      0.000003
# BsmtUnfSF       -0.000028
# 3SsnPorch       -0.000048
# 2ndFlrSF        -0.000060
# LowQualFinSF    -0.000179
# YrSold          -0.000273
# AgeRemodel      -0.000380
# Age             -0.002568
# BedroomAbvGr    -0.009436
# BsmtCond        -0.010063
# ExterCond       -0.033364
# KitchenAbvGr    -0.077642
# Name: 0, dtype: float64

# %%
# A plot of the scales of the linear regression coefficients.
log_slr_coef = np.log10(np.abs(slr.coef_))
fig, ax = plt.subplots()
sns.scatterplot(data = log_slr_coef)
plt.show()

plt.figure(figsize=(10,8))


residuals = y_train - y_pred_slr
plt.scatter(y_pred_slr, residuals)


plt.xlabel("predictions", fontsize=16)
plt.ylabel("residuals", fontsize=16)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="1000">

# %%
X = df.drop(columns = 'SalePrice')
y = np.log(df['SalePrice'])
numeric_train_unbounded = [x for x in numeric_unbounded if x!= 'SalePrice']
numeric_train = numeric_train_unbounded + numeric_ordinal + cat_ordinal
X = X[numeric_train]
from sklearn.model_selection import KFold
kfold = KFold(5, shuffle = True, random_state = 69)

mses = np.zeros((2,5))
i = 0

for train_index, test_index in kfold.split(X):
    x_t = X.iloc[train_index]
    scaler = StandardScaler()
    scaler.fit(x_t)
    x_t_scale = scaler.transform(x_t)
    y_t = y.iloc[train_index]
    
    x_ho = X.iloc[test_index]
    x_ho_scale = scaler.transform(x_ho)
    y_ho = y.iloc[test_index]
    
    pred0 = y_t.mean() * np.ones(len(x_ho))
    
    
    model = LinearRegression(copy_X = True)
    model.fit(x_t_scale,y_t)
    
    pred1 = (model.predict(x_ho_scale))
    
    mses[0,i] = mean_squared_error(np.exp(y_ho),np.exp(pred0), squared = False)
    
    mses[1,i] = mean_squared_error(np.exp(y_ho),np.exp(pred1), squared = False)
    
    i+=1

# %%
plt.figure(figsize=(8,5))

plt.scatter(np.zeros(5), 
            mses[0,:], 
            s=60, 
            c='white',
            edgecolor='black',
            label="Single Split")
plt.scatter(np.ones(5), 
            mses[1,:], 
            s=60, 
            c='white',
            edgecolor='black')

plt.scatter([0,1], np.mean(mses, axis=1), s=60, c='r', label="Mean")

plt.legend(fontsize=14)

plt.xticks([0,1],["Baseline", "OLS"], fontsize=14)
plt.yticks(fontsize=14)

plt.xlabel("Model", fontsize=16)
plt.ylabel("MSE", fontsize=16)

plt.show()

(np.mean(mses[1]))
# Out:
# <img src="data:image/png;base64,..." width="800">
# 23566.160756809142

# %% [markdown]
# ## Ridge Regression
# The OLS coefficient blowup is due to the artifically high model complexity and the multicollinearity indtroduced by the one hot encoding of the categorical variables. We can keep them in check by constraining them with lasso,ridge and elastic net regularization models and seeing how they control the coefficients.

# %%
#We use randomizedsearch CV to fit a Ridge Regression model to the data
X = df.drop(columns = 'SalePrice')
y = np.log(df['SalePrice'])

#Import Statements
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import RobustScaler


ridge_pipe = Pipeline([('scale',RobustScaler()),
                              ('ridge',Ridge())])


#Grid Search CV
parameters = {'ridge__alpha': np.logspace(0, 4, 10)}
ridge_cv = GridSearchCV(ridge_pipe,parameters,scoring='neg_mean_squared_error',cv=5)
ridge_cv.fit(X, y)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scale', RobustScaler()),
#                                        ('ridge', Ridge())]),
#              param_grid={'ridge__alpha': array([1.00000000e+00, 2.78255940e+00, 7.74263683e+00, 2.15443469e+01,
#        5.99484250e+01, 1.66810054e+02, 4.64158883e+02, 1.29154967e+03,
#        3.59381366e+03, 1.00000000e+04])},
#              scoring='neg_mean_squared_error')

# %%
print(ridge_cv.best_score_)
# Out:
# -0.013098555276993256

# %% [markdown]
# # Lasso Estimator

# %%
X = df.drop(columns = 'SalePrice')
y = np.log(df['SalePrice'])

from sklearn.linear_model import Lasso

lasso_pipe = Pipeline([('scale',RobustScaler()),
                              ('lasso',Lasso())])

parameters = {'lasso__alpha': np.logspace(-3, -1, 10)}
lasso_cv = GridSearchCV(lasso_pipe,parameters,scoring='neg_mean_squared_error',cv=5)
lasso_cv.fit(X,y)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scale', RobustScaler()),
#                                        ('lasso', Lasso())]),
#              param_grid={'lasso__alpha': array([0.001     , 0.0016681 , 0.00278256, 0.00464159, 0.00774264,
#        0.0129155 , 0.02154435, 0.03593814, 0.05994843, 0.1       ])},
#              scoring='neg_mean_squared_error')

# %%
lasso_cv.best_score_
# Out:
# -0.012632557343845071

# %% [markdown]
# # Comparison of the Ridge and Lasso Estimators
# Here we look at the coefficients of the best Ridge and Lasso estimators.

# %%
ridge_estimator = ridge_cv.best_estimator_
lasso_estimator = lasso_cv.best_estimator_

ridge_coefs = ridge_estimator['ridge'].coef_
lasso_coefs = lasso_estimator['lasso'].coef_

# %%
ridge_coefs = pd.DataFrame(ridge_coefs.reshape(1,-1), columns = X.columns)
lasso_coefs= pd.DataFrame(lasso_coefs.reshape(1,-1), columns = X.columns)

# %%
#Coefficients of the Ridge Regression
print_full(ridge_coefs.T[0].sort_values(ascending = False))
# Out:
# GrLivArea                0.152024
# OverallQual              0.106117
# Neighborhood_Crawfor     0.081905
# TotalBsmtSF              0.063698
# Neighborhood_StoneBr     0.045699
# MSZoning_RL              0.044740
# Exterior1st_BrkFace      0.044587
# GarageCars               0.040481
# Neighborhood_NridgHt     0.039466
# OverallCond              0.037734
# MSZoning_FV              0.036904
# Condition1_Norm          0.036251
# BsmtFinSF1               0.034343
# BldgType_1Fam            0.033938
# CentralAir_Y             0.031616
# Functional               0.031310
# Neighborhood_BrkSide     0.028763
# SaleType_New             0.028655
# Neighborhood_Somerst     0.028110
# SaleCondition_Normal     0.027940
# LotConfig_CulDSac        0.026413
# HalfBath                 0.025245
# BsmtFullBath             0.024856
# HeatingQC                0.024639
# FullBath                 0.023557
# MasVnrType_Stone         0.022386
# KitchenQual              0.022236
# Foundation_PConc         0.021242
# MSZoning_RH              0.020810
# SaleCondition_Partial    0.020542
# Neighborhood_ClearCr     0.019904
# Street_Pave              0.019321
# TotRmsAbvGrd             0.018774
# Heating_GasW             0.017730
# GarageQual               0.017648
# Exterior2nd_Wd Sdng      0.015962
# BsmtFinType1             0.015832
# HouseStyle_SLvl          0.015170
# WoodDeckSF               0.015120
# Neighborhood_Veenker     0.014169
# LandContour_HLS          0.014012
# LandSlope_Mod            0.013640
# MoSold_May               0.013578
# Foundation_Slab          0.013087
# SaleType_ConLD           0.013026
# ExterQual                0.012777
# BsmtExposure             0.012430
# BsmtFinType2_GLQ         0.012297
# PavedDrive_Y             0.011898
# BldgType_2fmCon          0.011358
# RoofStyle_Flat           0.011321
# RoofMatl_WdShngl         0.010057
# SaleCondition_AdjLand    0.009933
# Exterior1st_MetalSd      0.009845
# RoofMatl_Membran         0.009597
# LotArea                  0.009569
# Condition1_PosN          0.009309
# BsmtFinType2_ALQ         0.009297
# BsmtQual                 0.009212
# Exterior1st_WdShing      0.008678
# LotShape_IR2             0.008600
# SaleType_CWD             0.008577
# Heating_Wall             0.008328
# OpenPorchSF              0.008306
# HouseStyle_2.5Unf        0.007990
# SaleType_Oth             0.007748
# Condition2_Norm          0.007609
# Exterior1st_Stucco       0.007174
# SaleType_Con             0.007129
# LandSlope_Gtl            0.007081
# RoofStyle_Mansard        0.006996
# Foundation_Stone         0.006945
# Exterior2nd_Stone        0.006756
# Condition1_RRAn          0.006125
# Condition2_PosA          0.006017
# GarageType_Attchd        0.005968
# MasVnrArea               0.005941
# Exterior2nd_Plywood      0.005711
# Neighborhood_NoRidge     0.005686
# 2ndFlrSF                 0.005473
# GarageFinish             0.005406
# Exterior2nd_Stucco       0.005323
# GarageType_BuiltIn       0.005126
# SaleCondition_Alloca     0.004979
# LotConfig_Corner         0.004678
# Utilities_AllPub         0.004651
# Exterior2nd_AsphShn      0.004548
# MoSold_Jun               0.004191
# HouseStyle_1.5Unf        0.004128
# Neighborhood_NPkVill     0.004101
# RoofMatl_Metal           0.004046
# MoSold_Jul               0.003949
# Exterior2nd_CmentBd      0.003488
# MoSold_Dec               0.003392
# HouseStyle_1Story        0.003205
# Exterior2nd_VinylSd      0.003189
# Condition1_RRNn          0.003123
# PavedDrive_P             0.003101
# Exterior2nd_MetalSd      0.002946
# MasVnrType_None          0.002643
# LandContour_Bnk          0.002354
# Condition2_Feedr         0.001689
# Heating_GasA             0.001380
# RoofStyle_Shed           0.001356
# MoSold_Aug               0.001209
# Electrical_FuseF         0.001070
# Exterior2nd_ImStucc      0.000951
# MoSold_Apr               0.000937
# Exterior1st_AsphShn      0.000932
# Electrical_FuseA         0.000729
# Electrical_FuseP         0.000620
# BsmtHalfBath             0.000552
# RoofStyle_Hip            0.000448
# Condition2_RRNn          0.000426
# MoSold_Jan               0.000333
# ScreenPorch              0.000269
# 3SsnPorch                0.000165
# SaleType_ConLw           0.000152
# EnclosedPorch            0.000121
# Exterior1st_VinylSd      0.000039
# LowQualFinSF            -0.000061
# Condition1_PosA         -0.000106
# Exterior1st_ImStucc     -0.000318
# HouseStyle_1.5Fin       -0.000628
# Electrical_Mix          -0.000775
# LotShape_IR3            -0.000826
# Neighborhood_SWISU      -0.001104
# BldgType_Duplex         -0.001114
# Exterior1st_Stone       -0.001198
# GarageCond              -0.001413
# GarageType_Detchd       -0.001650
# Neighborhood_Blueste    -0.001853
# Exterior2nd_Other       -0.002268
# RoofMatl_Roll           -0.002803
# Condition2_RRAn         -0.002949
# LotShape_IR1            -0.003025
# Condition2_PosN         -0.003065
# Heating_OthW            -0.003246
# Exterior1st_CemntBd     -0.003334
# MoSold_Mar              -0.003488
# Exterior2nd_CBlock      -0.003520
# Exterior1st_CBlock      -0.003520
# Neighborhood_Sawyer     -0.003524
# LandContour_Lvl         -0.003580
# YrSold                  -0.003779
# Exterior2nd_HdBoard     -0.004114
# MoSold_Sep              -0.004333
# Heating_Floor           -0.004392
# Condition2_Artery       -0.004445
# BldgType_TwnhsE         -0.004485
# Utilities_NoSeWa        -0.004651
# Condition1_RRNe         -0.004659
# LotShape_Reg            -0.004749
# Electrical_SBrkr        -0.004823
# Exterior1st_AsbShng     -0.004923
# MasVnrType_BrkFace      -0.004940
# Foundation_CBlock       -0.004977
# BedroomAbvGr            -0.005098
# Condition2_RRAe         -0.005283
# MoSold_Feb              -0.005379
# GarageType_Basment      -0.005420
# RoofMatl_WdShake        -0.005544
# RoofMatl_Tar&Grv        -0.005618
# HouseStyle_SFoyer       -0.005960
# LotConfig_Inside        -0.006012
# BsmtFinType2_LwQ        -0.006201
# Exterior2nd_AsbShng     -0.006224
# BsmtFinType2_Unf        -0.006232
# MoSold_Oct              -0.006523
# Exterior1st_Plywood     -0.007359
# LotConfig_FR3           -0.007513
# RoofStyle_Gable         -0.007755
# MoSold_Nov              -0.007866
# Condition1_Feedr        -0.007906
# Exterior2nd_Wd Shng     -0.008630
# BsmtCond                -0.008663
# Neighborhood_NAmes      -0.008981
# Exterior1st_HdBoard     -0.009725
# RoofMatl_CompShg        -0.009734
# Exterior2nd_Brk Cmn     -0.009826
# ExterCond               -0.009866
# Neighborhood_Blmngtn    -0.009907
# BsmtFinType2_Rec        -0.009936
# BsmtUnfSF               -0.009983
# MSZoning_RM             -0.011135
# Neighborhood_Timber     -0.011136
# HouseStyle_2Story       -0.011538
# GarageType_CarPort      -0.011827
# SaleType_ConLI          -0.011891
# RoofStyle_Gambrel       -0.012366
# HouseStyle_2.5Fin       -0.012367
# Neighborhood_SawyerW    -0.012417
# LandContour_Low         -0.012786
# GarageType_2Types       -0.013272
# Exterior2nd_BrkFace     -0.014290
# Neighborhood_Gilbert    -0.014436
# PavedDrive_N            -0.014999
# Neighborhood_NWAmes     -0.016287
# Foundation_Wood         -0.016315
# Exterior1st_BrkComm     -0.016377
# SaleCondition_Family    -0.016418
# Neighborhood_BrDale     -0.016452
# Neighborhood_CollgCr    -0.016979
# LotConfig_FR2           -0.017566
# Street_Grvl             -0.019321
# Heating_Grav            -0.019800
# Foundation_BrkTil       -0.019983
# MasVnrType_BrkCmn       -0.020088
# Condition1_Artery       -0.020542
# LandSlope_Sev           -0.020721
# Neighborhood_Mitchel    -0.021145
# Condition1_RRAe         -0.021596
# Neighborhood_OldTown    -0.022198
# AgeRemodel              -0.022584
# SaleType_COD            -0.023523
# KitchenAbvGr            -0.024313
# Exterior1st_Wd Sdng     -0.024501
# BsmtFinType2_BLQ        -0.025496
# SaleType_WD             -0.029872
# Neighborhood_Edwards    -0.030884
# CentralAir_N            -0.031616
# Neighborhood_IDOTRR     -0.035759
# BldgType_Twnhs          -0.039697
# Neighborhood_MeadowV    -0.044741
# SaleCondition_Abnorml   -0.046975
# Age                     -0.059914
# MSZoning_C (all)        -0.091319
# Name: 0, dtype: float64

# %%
#Coefficients of the Lasso Regression
print_full(lasso_coefs[lasso_coefs != 0].T[0].sort_values(ascending = False))
# Out:
# GrLivArea                0.140770
# OverallQual              0.079082
# TotalBsmtSF              0.042260
# GarageCars               0.033745
# OverallCond              0.033417
# BsmtFinSF1               0.030545
# Neighborhood_Crawfor     0.019884
# Functional               0.018596
# LotArea                  0.018441
# KitchenQual              0.014625
# BsmtExposure             0.012442
# BldgType_1Fam            0.011998
# Neighborhood_NridgHt     0.011846
# SaleType_New             0.011691
# HeatingQC                0.011042
# ScreenPorch              0.010025
# BsmtFullBath             0.009165
# Exterior1st_BrkFace      0.008943
# Condition1_Norm          0.008583
# Neighborhood_StoneBr     0.008288
# Foundation_PConc         0.008150
# GarageQual               0.008088
# WoodDeckSF               0.007721
# GarageFinish             0.007518
# ExterQual                0.007356
# Neighborhood_Somerst     0.005597
# OpenPorchSF              0.005527
# LotConfig_CulDSac        0.005518
# MasVnrType_Stone         0.003928
# Neighborhood_BrkSide     0.003299
# BsmtFinType1             0.002818
# Neighborhood_ClearCr     0.002572
# BsmtQual                 0.002361
# PavedDrive_Y             0.002120
# RoofMatl_Membran         0.002088
# Neighborhood_Veenker     0.001431
# SaleType_ConLD           0.001425
# GarageType_Attchd        0.001236
# HalfBath                 0.001202
# BsmtFinType2_ALQ         0.000976
# MasVnrArea               0.000369
# Exterior1st_MetalSd      0.000183
# MoSold_May               0.000159
# LotShape_IR2             0.000143
# LandContour_HLS          0.000137
# PavedDrive_N            -0.000178
# MasVnrType_BrkCmn       -0.000219
# LotShape_Reg            -0.000493
# Exterior1st_HdBoard     -0.000673
# Neighborhood_OldTown    -0.000712
# GarageType_2Types       -0.000783
# Neighborhood_BrDale     -0.000909
# Foundation_BrkTil       -0.001023
# Foundation_Wood         -0.001056
# HouseStyle_2.5Fin       -0.001274
# Condition1_RRAe         -0.002080
# SaleType_WD             -0.002122
# Exterior1st_Wd Sdng     -0.002130
# Neighborhood_Edwards    -0.002710
# Heating_Grav            -0.003354
# Exterior1st_BrkComm     -0.003650
# SaleCondition_Family    -0.003756
# Condition1_Artery       -0.004151
# KitchenAbvGr            -0.004937
# Neighborhood_MeadowV    -0.005917
# BldgType_Twnhs          -0.006055
# CentralAir_N            -0.012563
# AgeRemodel              -0.013280
# SaleCondition_Abnorml   -0.016891
# MSZoning_RM             -0.021417
# MSZoning_C (all)        -0.027524
# Age                     -0.044943
# MoSold_Apr                    NaN
# MoSold_Aug                    NaN
# MoSold_Dec                    NaN
# MoSold_Feb                    NaN
# MoSold_Jan                    NaN
# MoSold_Jul                    NaN
# MoSold_Jun                    NaN
# MoSold_Mar                    NaN
# MoSold_Nov                    NaN
# MoSold_Oct                    NaN
# MoSold_Sep                    NaN
# MSZoning_FV                   NaN
# MSZoning_RH                   NaN
# MSZoning_RL                   NaN
# Street_Grvl                   NaN
# Street_Pave                   NaN
# LotShape_IR1                  NaN
# LotShape_IR3                  NaN
# LandContour_Bnk               NaN
# LandContour_Low               NaN
# LandContour_Lvl               NaN
# Utilities_AllPub              NaN
# Utilities_NoSeWa              NaN
# LotConfig_Corner              NaN
# LotConfig_FR2                 NaN
# LotConfig_FR3                 NaN
# LotConfig_Inside              NaN
# LandSlope_Gtl                 NaN
# LandSlope_Mod                 NaN
# LandSlope_Sev                 NaN
# Neighborhood_Blmngtn          NaN
# Neighborhood_Blueste          NaN
# Neighborhood_CollgCr          NaN
# Neighborhood_Gilbert          NaN
# Neighborhood_IDOTRR           NaN
# Neighborhood_Mitchel          NaN
# Neighborhood_NAmes            NaN
# Neighborhood_NPkVill          NaN
# Neighborhood_NWAmes           NaN
# Neighborhood_NoRidge          NaN
# Neighborhood_SWISU            NaN
# Neighborhood_Sawyer           NaN
# Neighborhood_SawyerW          NaN
# Neighborhood_Timber           NaN
# Condition1_Feedr              NaN
# Condition1_PosA               NaN
# Condition1_PosN               NaN
# Condition1_RRAn               NaN
# Condition1_RRNe               NaN
# Condition1_RRNn               NaN
# Condition2_Artery             NaN
# Condition2_Feedr              NaN
# Condition2_Norm               NaN
# Condition2_PosA               NaN
# Condition2_PosN               NaN
# Condition2_RRAe               NaN
# Condition2_RRAn               NaN
# Condition2_RRNn               NaN
# BldgType_2fmCon               NaN
# BldgType_Duplex               NaN
# BldgType_TwnhsE               NaN
# HouseStyle_1.5Fin             NaN
# HouseStyle_1.5Unf             NaN
# HouseStyle_1Story             NaN
# HouseStyle_2.5Unf             NaN
# HouseStyle_2Story             NaN
# HouseStyle_SFoyer             NaN
# HouseStyle_SLvl               NaN
# RoofStyle_Flat                NaN
# RoofStyle_Gable               NaN
# RoofStyle_Gambrel             NaN
# RoofStyle_Hip                 NaN
# RoofStyle_Mansard             NaN
# RoofStyle_Shed                NaN
# RoofMatl_CompShg              NaN
# RoofMatl_Metal                NaN
# RoofMatl_Roll                 NaN
# RoofMatl_Tar&Grv              NaN
# RoofMatl_WdShake              NaN
# RoofMatl_WdShngl              NaN
# Exterior1st_AsbShng           NaN
# Exterior1st_AsphShn           NaN
# Exterior1st_CBlock            NaN
# Exterior1st_CemntBd           NaN
# Exterior1st_ImStucc           NaN
# Exterior1st_Plywood           NaN
# Exterior1st_Stone             NaN
# Exterior1st_Stucco            NaN
# Exterior1st_VinylSd           NaN
# Exterior1st_WdShing           NaN
# Exterior2nd_AsbShng           NaN
# Exterior2nd_AsphShn           NaN
# Exterior2nd_Brk Cmn           NaN
# Exterior2nd_BrkFace           NaN
# Exterior2nd_CBlock            NaN
# Exterior2nd_CmentBd           NaN
# Exterior2nd_HdBoard           NaN
# Exterior2nd_ImStucc           NaN
# Exterior2nd_MetalSd           NaN
# Exterior2nd_Other             NaN
# Exterior2nd_Plywood           NaN
# Exterior2nd_Stone             NaN
# Exterior2nd_Stucco            NaN
# Exterior2nd_VinylSd           NaN
# Exterior2nd_Wd Sdng           NaN
# Exterior2nd_Wd Shng           NaN
# MasVnrType_BrkFace            NaN
# MasVnrType_None               NaN
# Foundation_CBlock             NaN
# Foundation_Slab               NaN
# Foundation_Stone              NaN
# BsmtFinType2_BLQ              NaN
# BsmtFinType2_GLQ              NaN
# BsmtFinType2_LwQ              NaN
# BsmtFinType2_Rec              NaN
# BsmtFinType2_Unf              NaN
# Heating_Floor                 NaN
# Heating_GasA                  NaN
# Heating_GasW                  NaN
# Heating_OthW                  NaN
# Heating_Wall                  NaN
# CentralAir_Y                  NaN
# Electrical_FuseA              NaN
# Electrical_FuseF              NaN
# Electrical_FuseP              NaN
# Electrical_Mix                NaN
# Electrical_SBrkr              NaN
# GarageType_Basment            NaN
# GarageType_BuiltIn            NaN
# GarageType_CarPort            NaN
# GarageType_Detchd             NaN
# PavedDrive_P                  NaN
# SaleType_COD                  NaN
# SaleType_CWD                  NaN
# SaleType_Con                  NaN
# SaleType_ConLI                NaN
# SaleType_ConLw                NaN
# SaleType_Oth                  NaN
# SaleCondition_AdjLand         NaN
# SaleCondition_Alloca          NaN
# SaleCondition_Normal          NaN
# SaleCondition_Partial         NaN
# BsmtHalfBath                  NaN
# FullBath                      NaN
# BedroomAbvGr                  NaN
# TotRmsAbvGrd                  NaN
# YrSold                        NaN
# ExterCond                     NaN
# BsmtCond                      NaN
# GarageCond                    NaN
# BsmtUnfSF                     NaN
# 2ndFlrSF                      NaN
# LowQualFinSF                  NaN
# EnclosedPorch                 NaN
# 3SsnPorch                     NaN
# Name: 0, dtype: float64

# %%
y_hat = ridge_estimator.predict(X)
residuals = y - y_hat

plt.figure(figsize=(10,8))

plt.scatter(y_hat, residuals)


plt.xlabel("predictions", fontsize=16)
plt.ylabel("residuals", fontsize=16)

plt.show()

plt.figure(figsize=(10,8))

plt.scatter(y, y_hat)


plt.xlabel("y", fontsize=16)
plt.ylabel("y_hat", fontsize=16)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
y_hat = lasso_estimator.predict(X)
residuals = y - y_hat

plt.figure(figsize=(10,8))

plt.scatter(y_hat, residuals)
plt.xlabel("predictions", fontsize=16)
plt.ylabel("residuals", fontsize=16)

plt.show()

plt.figure(figsize=(10,8))

plt.scatter(y, y_hat)


plt.xlabel("y", fontsize=16)
plt.ylabel("y_hat", fontsize=16)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ## Elastic Net
# A mixture of both the lasso and the ridge regression.

# %%
X = df.drop(columns = 'SalePrice')
y = np.log(df['SalePrice'])
from sklearn.linear_model import ElasticNet

elastic_pipe = Pipeline([('scale',RobustScaler()),
                              ('elastic',ElasticNet())])
parameters = {'elastic__alpha': np.logspace(-3, 0, 10), 'elastic__l1_ratio': [.1, .5, .7, .9, .95, .99,
1]}

elastic_cv = GridSearchCV(elastic_pipe,parameters,scoring='neg_mean_squared_error',cv=5)
elastic_cv.fit(X,y)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scale', StandardScaler()),
#                                        ('elastic', ElasticNet())]),
#              param_grid={'elastic__alpha': array([0.001     , 0.00215443, 0.00464159, 0.01      , 0.02154435,
#        0.04641589, 0.1       , 0.21544347, 0.46415888, 1.        ]),
#                          'elastic__l1_ratio': [0.1, 0.5, 0.7, 0.9, 0.95, 0.99,
#                                                1]},
#              scoring='neg_mean_squared_error')

# %%
elastic_estimator = elastic_cv.best_estimator_
elastic_coefs = elastic_estimator['elastic'].coef_
elastic_coefs = pd.DataFrame(elastic_coefs.reshape(1,-1), columns = X.columns)
print_full(elastic_coefs[elastic_coefs != 0].T[0].sort_values(ascending = False))
# Out:
# GrLivArea                0.141101
# OverallQual              0.078004
# TotalBsmtSF              0.042158
# OverallCond              0.033792
# GarageCars               0.033492
# BsmtFinSF1               0.030322
# Neighborhood_Crawfor     0.020356
# Functional               0.019066
# LotArea                  0.018509
# KitchenQual              0.014440
# Neighborhood_NridgHt     0.012540
# BsmtExposure             0.012468
# BldgType_1Fam            0.012455
# SaleType_New             0.011514
# HeatingQC                0.011110
# ScreenPorch              0.010375
# BsmtFullBath             0.009441
# Exterior1st_BrkFace      0.009338
# Condition1_Norm          0.009113
# Neighborhood_StoneBr     0.008968
# GarageQual               0.008363
# Foundation_PConc         0.008288
# WoodDeckSF               0.008138
# GarageFinish             0.007226
# ExterQual                0.006973
# Neighborhood_Somerst     0.006111
# OpenPorchSF              0.005881
# LotConfig_CulDSac        0.005839
# MasVnrType_Stone         0.004303
# Neighborhood_BrkSide     0.003893
# BsmtFinType1             0.003099
# Neighborhood_ClearCr     0.002813
# RoofMatl_Membran         0.002513
# PavedDrive_Y             0.002429
# BsmtQual                 0.002256
# SaleType_ConLD           0.002076
# Neighborhood_Veenker     0.001776
# HalfBath                 0.001698
# GarageType_Attchd        0.001333
# BsmtFinType2_ALQ         0.001293
# MasVnrArea               0.000712
# MoSold_May               0.000696
# Exterior1st_MetalSd      0.000642
# LandContour_HLS          0.000523
# LotShape_IR2             0.000494
# CentralAir_Y             0.000483
# Heating_GasW             0.000479
# Foundation_Stone         0.000222
# BsmtFinType2_GLQ         0.000119
# MSZoning_FV              0.000001
# PavedDrive_N            -0.000052
# BsmtFinType2_BLQ        -0.000127
# LotShape_Reg            -0.000331
# MasVnrType_BrkCmn       -0.000687
# Neighborhood_OldTown    -0.001009
# Neighborhood_BrDale     -0.001184
# Exterior1st_HdBoard     -0.001264
# GarageType_2Types       -0.001303
# Foundation_BrkTil       -0.001461
# Foundation_Wood         -0.001536
# HouseStyle_2.5Fin       -0.001722
# Exterior1st_Wd Sdng     -0.002400
# Condition1_RRAe         -0.002425
# SaleType_WD             -0.002598
# Neighborhood_Edwards    -0.003108
# Heating_Grav            -0.003653
# Exterior1st_BrkComm     -0.004078
# SaleCondition_Family    -0.004105
# Condition1_Artery       -0.004223
# KitchenAbvGr            -0.004980
# BldgType_Twnhs          -0.006357
# Neighborhood_MeadowV    -0.006441
# CentralAir_N            -0.012151
# AgeRemodel              -0.013281
# SaleCondition_Abnorml   -0.017121
# MSZoning_RM             -0.021136
# MSZoning_C (all)        -0.028203
# Age                     -0.045133
# MoSold_Apr                    NaN
# MoSold_Aug                    NaN
# MoSold_Dec                    NaN
# MoSold_Feb                    NaN
# MoSold_Jan                    NaN
# MoSold_Jul                    NaN
# MoSold_Jun                    NaN
# MoSold_Mar                    NaN
# MoSold_Nov                    NaN
# MoSold_Oct                    NaN
# MoSold_Sep                    NaN
# MSZoning_RH                   NaN
# MSZoning_RL                   NaN
# Street_Grvl                   NaN
# Street_Pave                   NaN
# LotShape_IR1                  NaN
# LotShape_IR3                  NaN
# LandContour_Bnk               NaN
# LandContour_Low               NaN
# LandContour_Lvl               NaN
# Utilities_AllPub              NaN
# Utilities_NoSeWa              NaN
# LotConfig_Corner              NaN
# LotConfig_FR2                 NaN
# LotConfig_FR3                 NaN
# LotConfig_Inside              NaN
# LandSlope_Gtl                 NaN
# LandSlope_Mod                 NaN
# LandSlope_Sev                 NaN
# Neighborhood_Blmngtn          NaN
# Neighborhood_Blueste          NaN
# Neighborhood_CollgCr          NaN
# Neighborhood_Gilbert          NaN
# Neighborhood_IDOTRR           NaN
# Neighborhood_Mitchel          NaN
# Neighborhood_NAmes            NaN
# Neighborhood_NPkVill          NaN
# Neighborhood_NWAmes           NaN
# Neighborhood_NoRidge          NaN
# Neighborhood_SWISU            NaN
# Neighborhood_Sawyer           NaN
# Neighborhood_SawyerW          NaN
# Neighborhood_Timber           NaN
# Condition1_Feedr              NaN
# Condition1_PosA               NaN
# Condition1_PosN               NaN
# Condition1_RRAn               NaN
# Condition1_RRNe               NaN
# Condition1_RRNn               NaN
# Condition2_Artery             NaN
# Condition2_Feedr              NaN
# Condition2_Norm               NaN
# Condition2_PosA               NaN
# Condition2_PosN               NaN
# Condition2_RRAe               NaN
# Condition2_RRAn               NaN
# Condition2_RRNn               NaN
# BldgType_2fmCon               NaN
# BldgType_Duplex               NaN
# BldgType_TwnhsE               NaN
# HouseStyle_1.5Fin             NaN
# HouseStyle_1.5Unf             NaN
# HouseStyle_1Story             NaN
# HouseStyle_2.5Unf             NaN
# HouseStyle_2Story             NaN
# HouseStyle_SFoyer             NaN
# HouseStyle_SLvl               NaN
# RoofStyle_Flat                NaN
# RoofStyle_Gable               NaN
# RoofStyle_Gambrel             NaN
# RoofStyle_Hip                 NaN
# RoofStyle_Mansard             NaN
# RoofStyle_Shed                NaN
# RoofMatl_CompShg              NaN
# RoofMatl_Metal                NaN
# RoofMatl_Roll                 NaN
# RoofMatl_Tar&Grv              NaN
# RoofMatl_WdShake              NaN
# RoofMatl_WdShngl              NaN
# Exterior1st_AsbShng           NaN
# Exterior1st_AsphShn           NaN
# Exterior1st_CBlock            NaN
# Exterior1st_CemntBd           NaN
# Exterior1st_ImStucc           NaN
# Exterior1st_Plywood           NaN
# Exterior1st_Stone             NaN
# Exterior1st_Stucco            NaN
# Exterior1st_VinylSd           NaN
# Exterior1st_WdShing           NaN
# Exterior2nd_AsbShng           NaN
# Exterior2nd_AsphShn           NaN
# Exterior2nd_Brk Cmn           NaN
# Exterior2nd_BrkFace           NaN
# Exterior2nd_CBlock            NaN
# Exterior2nd_CmentBd           NaN
# Exterior2nd_HdBoard           NaN
# Exterior2nd_ImStucc           NaN
# Exterior2nd_MetalSd           NaN
# Exterior2nd_Other             NaN
# Exterior2nd_Plywood           NaN
# Exterior2nd_Stone             NaN
# Exterior2nd_Stucco            NaN
# Exterior2nd_VinylSd           NaN
# Exterior2nd_Wd Sdng           NaN
# Exterior2nd_Wd Shng           NaN
# MasVnrType_BrkFace            NaN
# MasVnrType_None               NaN
# Foundation_CBlock             NaN
# Foundation_Slab               NaN
# BsmtFinType2_LwQ              NaN
# BsmtFinType2_Rec              NaN
# BsmtFinType2_Unf              NaN
# Heating_Floor                 NaN
# Heating_GasA                  NaN
# Heating_OthW                  NaN
# Heating_Wall                  NaN
# Electrical_FuseA              NaN
# Electrical_FuseF              NaN
# Electrical_FuseP              NaN
# Electrical_Mix                NaN
# Electrical_SBrkr              NaN
# GarageType_Basment            NaN
# GarageType_BuiltIn            NaN
# GarageType_CarPort            NaN
# GarageType_Detchd             NaN
# PavedDrive_P                  NaN
# SaleType_COD                  NaN
# SaleType_CWD                  NaN
# SaleType_Con                  NaN
# SaleType_ConLI                NaN
# SaleType_ConLw                NaN
# SaleType_Oth                  NaN
# SaleCondition_AdjLand         NaN
# SaleCondition_Alloca          NaN
# SaleCondition_Normal          NaN
# SaleCondition_Partial         NaN
# BsmtHalfBath                  NaN
# FullBath                      NaN
# BedroomAbvGr                  NaN
# TotRmsAbvGrd                  NaN
# YrSold                        NaN
# ExterCond                     NaN
# BsmtCond                      NaN
# GarageCond                    NaN
# BsmtUnfSF                     NaN
# 2ndFlrSF                      NaN
# LowQualFinSF                  NaN
# EnclosedPorch                 NaN
# 3SsnPorch                     NaN
# Name: 0, dtype: float64

# %%
y_hat = elastic_estimator.predict(X)
residuals = y - y_hat

plt.figure(figsize=(10,8))

plt.scatter(y_hat, residuals)


plt.xlabel("predictions", fontsize=16)
plt.ylabel("residuals", fontsize=16)

plt.show()

plt.figure(figsize=(10,8))

plt.scatter(y, y_hat)


plt.xlabel("y", fontsize=16)
plt.ylabel("y_hat", fontsize=16)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
print(mean_squared_error(np.exp(y),np.exp(y_hat), squared = False))
# Out:
# 18877.903993937525
